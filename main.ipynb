# %%
# %load_ext autoreload
# %autoreload 2

# %%
from main import main

# %%
main()
# Out:
# === EDA: Descriptive Statistics ===
#              epoch           sma         ecc         inc  mean_anomaly  \
# count   100.000000    100.000000  100.000000  100.000000    100.000000
# mean   -445.200000  42246.942400    0.166060   16.300374    171.546071
# std    2460.173674     62.461688    0.191264    8.256317    105.011285
# min   -4995.000000  41933.400000    0.006011    1.214600      0.337700
# 25%   -2637.500000  42206.542500    0.054115   10.893950     77.387475
# 50%    -335.000000  42251.600000    0.094615   15.096750    167.270850
# 75%    1330.000000  42289.875000    0.186622   18.717175    258.053825
# max    6315.000000  42347.660000    0.834790   42.360000    360.347600
#
#        arg_perigee        raan  area_mass_ratio   gen_epoch       gen_sma  \
# count   100.000000  100.000000       100.000000   100.00000    100.000000
# mean    191.424464  137.429013        10.983837 -3604.30000  42254.820000
# ...
